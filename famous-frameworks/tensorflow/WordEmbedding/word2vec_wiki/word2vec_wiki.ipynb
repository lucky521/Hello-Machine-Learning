# %%
# python 3
# -*- coding: utf-8 -*-
from __future__ import division, print_function, absolute_import

import collections
import os
import random
import urllib.request
import zipfile

import numpy as np
import tensorflow as tf

# %%
# Training Parameters
learning_rate = 0.1
batch_size = 128
num_steps = 3000000
display_step = 10000
eval_step = 200000

# Evaluation Parameters
eval_words = [b'five', b'of', b'going', b'hardware', b'american', b'britain']

# Word2Vec Parameters
embedding_size = 200 # Dimension of the embedding vector
max_vocabulary_size = 50000 # Total number of different words in the vocabulary
min_occurrence = 10 # Remove all words that does not appears at least n times
skip_window = 3 # How many words to consider left and right
num_skips = 2 # How many times to reuse an input to generate a label
num_sampled = 64 # Number of negative examples to sample

# %%
# Download a small chunk of Wikipedia articles collection
url = 'http://mattmahoney.net/dc/text8.zip'
data_path = 'text8.zip'
if not os.path.exists(data_path):
    print("Downloading the dataset... (It may take some time)")
    filename, _ = urllib.request.urlretrieve(url, data_path)
    print("Done!")
# Unzip the dataset file. Text has already been processed
with zipfile.ZipFile(data_path) as f:
    text_words = f.read(f.namelist()[0]).lower().split()

print("Finish loading {}, Size of zipfile is {}.".format(data_path, len(text_words)))
# Out:
# Downloading the dataset... (It may take some time)
# Done!
# Finish loading text8.zip, Size of zipfile is 17005207.

# %%
# Build the dictionary and replace rare words with UNK token
count = [('UNK', -1)]
# Retrieve the most common words
count.extend(collections.Counter(text_words).most_common(max_vocabulary_size - 1))

# Remove samples with less than 'min_occurrence' occurrences
for i in range(len(count) - 1, -1, -1):
    if count[i][1] < min_occurrence:
        count.pop(i)
    else:
        # The collection is ordered, so stop when 'min_occurrence' is reached
        break

# Compute the vocabulary size
vocabulary_size = len(count)
# Assign an id to each word
word2id = dict()
for i, (word, _)in enumerate(count):
    word2id[word] = i

data = list()
unk_count = 0
for word in text_words:
    # Retrieve a word id, or assign it index 0 ('UNK') if not in dictionary
    index = word2id.get(word, 0)
    if index == 0:
        unk_count += 1
    data.append(index)
count[0] = ('UNK', unk_count)
id2word = dict(zip(word2id.values(), word2id.keys()))

print("Words count:", len(text_words))
print("Unique words:", len(set(text_words)))
print("Vocabulary size:", vocabulary_size)
print("Most common words:", count[:50])
# Out:
# Words count: 17005207
# Unique words: 253854
# Vocabulary size: 47135
# Most common words: [('UNK', 444176), (b'the', 1061396), (b'of', 593677), (b'and', 416629), (b'one', 411764), (b'in', 372201), (b'a', 325873), (b'to', 316376), (b'zero', 264975), (b'nine', 250430), (b'two', 192644), (b'is', 183153), (b'as', 131815), (b'eight', 125285), (b'for', 118445), (b's', 116710), (b'five', 115789), (b'three', 114775), (b'was', 112807), (b'by', 111831), (b'that', 109510), (b'four', 108182), (b'six', 102145), (b'seven', 99683), (b'with', 95603), (b'on', 91250), (b'are', 76527), (b'it', 73334), (b'from', 72871), (b'or', 68945), (b'his', 62603), (b'an', 61925), (b'be', 61281), (b'this', 58832), (b'which', 54788), (b'at', 54576), (b'he', 53573), (b'also', 44358), (b'not', 44033), (b'have', 39712), (b'were', 39086), (b'has', 37866), (b'but', 35358), (b'other', 32433), (b'their', 31523), (b'its', 29567), (b'first', 28810), (b'they', 28553), (b'some', 28161), (b'had', 28100)]

# %%
data_index = 0
# Generate training batch for the skip-gram model
def next_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)  # init batch array
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  # init label array
    # get window size (words left and right + current one)
    span = 2 * skip_window + 1
    buffer = collections.deque(maxlen=span) # init list
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]

        if data_index == len(data):
            buffer.extend(data[0:span])
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
# Input data
X = tf.placeholder(tf.int32, shape=[None])
# Input label
Y = tf.placeholder(tf.int32, shape=[None, 1])

# Ensure the following ops & var are assigned on CPU
# (some ops are not compatible on GPU)
with tf.device('/cpu:0'):
    # Create the embedding variable (each row represent a word embedding vector)
    embedding = tf.Variable(tf.random_normal([vocabulary_size, embedding_size]))
    
    # Lookup the corresponding embedding vectors for each sample in X
    X_embed = tf.nn.embedding_lookup(embedding, X)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(tf.random_normal([vocabulary_size, embedding_size]))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

# Compute the average NCE loss for the batch
loss_op = tf.reduce_mean(
    tf.nn.nce_loss(weights=nce_weights,
                   biases=nce_biases,
                   labels=Y,
                   inputs=X_embed,
                   num_sampled=num_sampled,
                   num_classes=vocabulary_size))

# Define the optimizer
optimizer = tf.train.GradientDescentOptimizer(learning_rate)
train_op = optimizer.minimize(loss_op)

# Evaluation
# Compute the cosine similarity between input data embedding and every embedding vectors
X_embed_norm = X_embed / tf.sqrt(tf.reduce_sum(tf.square(X_embed)))
embedding_norm = embedding / tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True))
cosine_sim_op = tf.matmul(X_embed_norm, embedding_norm, transpose_b=True)

# %%
# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

with tf.Session() as sess:

    # Run the initializer
    sess.run(init)

    # Testing data
    x_test = np.array([word2id[w] for w in eval_words])

    average_loss = 0
    for step in range(1, num_steps + 1):
        # Get a new batch of data
        batch_x, batch_y = next_batch(batch_size, num_skips, skip_window)
        # Run training op
        _, loss = sess.run([train_op, loss_op], feed_dict={X: batch_x, Y: batch_y})
        average_loss += loss

        if step % display_step == 0 or step == 1:
            if step > 1:
                average_loss /= display_step
            print("Step " + str(step) + ", Average Loss= " + \
                  "{:.4f}".format(average_loss))
            average_loss = 0

        # Evaluation
        if step % eval_step == 0 or step == 1:
            print("Evaluation...")
            sim = sess.run(cosine_sim_op, feed_dict={X: x_test})
            for i in range(len(eval_words)):
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = '"%s" nearest neighbors:' % eval_words[i]
                for k in range(top_k):
                    log_str = '%s %s,' % (log_str, id2word[nearest[k]])
                print(log_str)

    saver = tf.train.Saver()
    saver.save(sess, "./model-wiki/model.ckpt")
# Out:
# Step 1, Average Loss= 546.0007
# Evaluation...
# "b'five'" nearest neighbors: b'hawthorne', b'wargame', b'alternate', b'venturi', b'thaw', b'neighboring', b'overwhelming', b'ppg',
# "b'of'" nearest neighbors: b'bureaucracies', b'cellular', b'crept', b'ghibli', b'covariance', b'amnon', b'stadiums', b'tidings',
# "b'going'" nearest neighbors: b'trailers', b'indicted', b'captures', b'architect', b'heschel', b'characterise', b'refinement', b'hiram',
# "b'hardware'" nearest neighbors: b'julia', b'intimacy', b'bertolt', b'radios', b'replacing', b'achievable', b'llc', b'habitat',
# "b'american'" nearest neighbors: b'annealing', b'colombian', b'martinez', b'walters', b'hellish', b'crist', b'sligo', b'levee',
# "b'britain'" nearest neighbors: b'correlatives', b'allegation', b'acceptability', b'adversarial', b'contrasting', b'chosen', b'proverbial', b'corn',
# Step 10000, Average Loss= 199.4634
# Step 20000, Average Loss= 94.1371
# Step 30000, Average Loss= 65.3162
# Step 40000, Average Loss= 50.9172
# Step 50000, Average Loss= 41.2971
# Step 60000, Average Loss= 36.3604
# Step 70000, Average Loss= 32.0594
# Step 80000, Average Loss= 29.6052
# Step 90000, Average Loss= 27.3105
# Step 100000, Average Loss= 24.7733
# Step 110000, Average Loss= 23.3548
# Step 120000, Average Loss= 21.1258
# Step 130000, Average Loss= 20.4809
# Step 140000, Average Loss= 19.2986
# Step 150000, Average Loss= 18.7452
# Step 160000, Average Loss= 17.6442
# Step 170000, Average Loss= 17.0030
# Step 180000, Average Loss= 16.3590
# Step 190000, Average Loss= 15.4416
# Step 200000, Average Loss= 14.6179
# Evaluation...
# "b'five'" nearest neighbors: b'three', b'four', b'six', b'two', b'seven', b'eight', b'nine', b'zero',
# "b'of'" nearest neighbors: b'the', b'a', b'first', b'was', b'when', b'is', b'by', b'on',
# "b'going'" nearest neighbors: b'some', b'is', b'or', b'which', b'then', b'used', b'also', b'in',
# "b'hardware'" nearest neighbors: b'him', b'the', b'were', b'his', b'them', b'was', b'in', b'this',
# "b'american'" nearest neighbors: UNK, b'and', b'in', b's', b'with', b'the', b'after', b'when',
# "b'britain'" nearest neighbors: b'in', b'the', b'c', b's', b'and', b'of', b'under', b'a',
# Step 210000, Average Loss= 14.4361
# Step 220000, Average Loss= 14.9810
# Step 230000, Average Loss= 13.5935
# Step 240000, Average Loss= 14.0315
# Step 250000, Average Loss= 12.7192
# Step 260000, Average Loss= 12.8542
# Step 270000, Average Loss= 12.6745
# Step 280000, Average Loss= 11.7691
# Step 290000, Average Loss= 11.3044
# Step 300000, Average Loss= 11.4680
# Step 310000, Average Loss= 10.7995
# Step 320000, Average Loss= 10.8435
# Step 330000, Average Loss= 10.5595
# Step 340000, Average Loss= 10.4458
# Step 350000, Average Loss= 10.6598
# Step 360000, Average Loss= 10.3229
# Step 370000, Average Loss= 10.1936
# Step 380000, Average Loss= 10.0134
# Step 390000, Average Loss= 9.7506
# Step 400000, Average Loss= 9.7011
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'three', b'six', b'two', b'seven', b'eight', b'one', b'zero',
# "b'of'" nearest neighbors: b'and', b'with', b'the', b'or', b'for', b'all', b'a', b'its',
# "b'going'" nearest neighbors: b'using', b'he', b'now', b'and', b'became', b'for', b'of', b'then',
# "b'hardware'" nearest neighbors: b'law', b'them', b'usually', b'out', b'a', b'then', b'because', UNK,
# "b'american'" nearest neighbors: b's', b'british', b'in', b'after', b'since', b'and', b'about', b'on',
# "b'britain'" nearest neighbors: b'an', b'see', b'against', b'its', b'high', b'known', b'under', b'by',
# Step 410000, Average Loss= 9.8186
# Step 420000, Average Loss= 9.2752
# Step 430000, Average Loss= 9.5125
# Step 440000, Average Loss= 9.2122
# Step 450000, Average Loss= 9.2410
# Step 460000, Average Loss= 8.9166
# Step 470000, Average Loss= 8.6235
# Step 480000, Average Loss= 8.7603
# Step 490000, Average Loss= 9.0446
# Step 500000, Average Loss= 8.9101
# Step 510000, Average Loss= 8.5747
# Step 520000, Average Loss= 8.6251
# Step 530000, Average Loss= 8.6342
# Step 540000, Average Loss= 8.3666
# Step 550000, Average Loss= 8.1965
# Step 560000, Average Loss= 8.1917
# Step 570000, Average Loss= 8.1323
# Step 580000, Average Loss= 7.9850
# Step 590000, Average Loss= 8.0824
# Step 600000, Average Loss= 7.8729
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'three', b'six', b'two', b'seven', b'one', b'eight', b'zero',
# "b'of'" nearest neighbors: b'and', b'the', b'including', b'in', b'for', b'an', b'all', b'its',
# "b'going'" nearest neighbors: b'then', b'these', b'when', b'which', b'into', b'other', b'several', b'used',
# "b'hardware'" nearest neighbors: b'down', b'military', b'out', b'their', b'own', b'who', b'several', b'great',
# "b'american'" nearest neighbors: b'german', b'french', b'english', b's', b'john', b'since', b'british', b'in',
# "b'britain'" nearest neighbors: b'high', b'an', b'country', b'also', b'against', b'or', b'see', b'include',
# Step 610000, Average Loss= 7.9578
# Step 620000, Average Loss= 8.0630
# Step 630000, Average Loss= 7.8421
# Step 640000, Average Loss= 7.8683
# Step 650000, Average Loss= 7.6909
# Step 660000, Average Loss= 7.7245
# Step 670000, Average Loss= 7.6028
# Step 680000, Average Loss= 7.7574
# Step 690000, Average Loss= 7.5794
# Step 700000, Average Loss= 7.5863
# Step 710000, Average Loss= 7.4952
# Step 720000, Average Loss= 7.4462
# Step 730000, Average Loss= 7.3297
# Step 740000, Average Loss= 7.1552
# Step 750000, Average Loss= 7.4750
# Step 760000, Average Loss= 7.2787
# Step 770000, Average Loss= 7.4911
# Step 780000, Average Loss= 7.1691
# Step 790000, Average Loss= 7.2501
# Step 800000, Average Loss= 7.2972
# Evaluation...
# "b'five'" nearest neighbors: b'three', b'four', b'six', b'two', b'eight', b'seven', b'nine', b'one',
# "b'of'" nearest neighbors: b'the', b'and', b'in', b'from', b'for', b'including', b'include', b'a',
# "b'going'" nearest neighbors: b'these', b'an', b'common', b'now', b'especially', b'are', b'later', b'which',
# "b'hardware'" nearest neighbors: b'down', b'own', b'out', b'due', b'later', b'military', b'man', b'developed',
# "b'american'" nearest neighbors: b'born', b'english', b'b', b'french', b'british', b'd', b'german', b'john',
# "b'britain'" nearest neighbors: b'high', b'include', b'free', b'within', b'long', b'now', b'modern', b'country',
# Step 810000, Average Loss= 7.1110
# Step 820000, Average Loss= 7.0318
# Step 830000, Average Loss= 7.1677
# Step 840000, Average Loss= 7.0018
# Step 850000, Average Loss= 7.0198
# Step 860000, Average Loss= 7.0467
# Step 870000, Average Loss= 6.9382
# Step 880000, Average Loss= 7.0785
# Step 890000, Average Loss= 7.0267
# Step 900000, Average Loss= 6.9644
# Step 910000, Average Loss= 7.0094
# Step 920000, Average Loss= 6.8255
# Step 930000, Average Loss= 6.8859
# Step 940000, Average Loss= 6.9475
# Step 950000, Average Loss= 6.7439
# Step 960000, Average Loss= 6.9123
# Step 970000, Average Loss= 6.7396
# Step 980000, Average Loss= 6.8558
# Step 990000, Average Loss= 6.6584
# Step 1000000, Average Loss= 6.5424
# Evaluation...
# "b'five'" nearest neighbors: b'three', b'four', b'six', b'seven', b'eight', b'two', b'nine', b'zero',
# "b'of'" nearest neighbors: b'the', b'first', b'following', b'from', b'became', b'including', b'in', b'under',
# "b'going'" nearest neighbors: b'several', b'place', b'however', b'or', b'only', b'both', b'is', b'some',
# "b'hardware'" nearest neighbors: b'work', b'down', b'military', b'out', b'where', b'she', b'he', b'own',
# "b'american'" nearest neighbors: b'born', b'd', b'b', UNK, b'nine', b'john', b'french', b'one',
# "b'britain'" nearest neighbors: b'within', b'country', b'high', b'in', b'through', b's', b'from', b'on',
# Step 1010000, Average Loss= 6.6173
# Step 1020000, Average Loss= 6.8252
# Step 1030000, Average Loss= 6.6801
# Step 1040000, Average Loss= 6.6759
# Step 1050000, Average Loss= 6.6292
# Step 1060000, Average Loss= 6.6619
# Step 1070000, Average Loss= 6.6593
# Step 1080000, Average Loss= 6.5401
# Step 1090000, Average Loss= 6.5453
# Step 1100000, Average Loss= 6.6246
# Step 1110000, Average Loss= 6.4733
# Step 1120000, Average Loss= 6.5681
# Step 1130000, Average Loss= 6.4464
# Step 1140000, Average Loss= 6.5354
# Step 1150000, Average Loss= 6.6433
# Step 1160000, Average Loss= 6.4983
# Step 1170000, Average Loss= 6.5337
# Step 1180000, Average Loss= 6.4405
# Step 1190000, Average Loss= 6.4762
# Step 1200000, Average Loss= 6.4060
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'three', b'six', b'two', b'seven', b'eight', b'nine', b'zero',
# "b'of'" nearest neighbors: b'the', b'and', b'in', b'including', b'for', b'following', b'with', b'from',
# "b'going'" nearest neighbors: b'place', b'these', b'several', b'for', b'however', b'their', b'has', b'control',
# "b'hardware'" nearest neighbors: b'father', b'out', b'work', b'a', b'itself', b'by', b'making', b'forces',
# "b'american'" nearest neighbors: b'born', b'german', b'd', UNK, b'john', b'b', b'british', b'french',
# "b'britain'" nearest neighbors: b'high', b'country', b'at', b'level', b'within', b'europe', b'along', b'its',
# Step 1210000, Average Loss= 6.5289
# Step 1220000, Average Loss= 6.3697
# Step 1230000, Average Loss= 6.4436
# Step 1240000, Average Loss= 6.4126
# Step 1250000, Average Loss= 6.3676
# Step 1260000, Average Loss= 6.3348
# Step 1270000, Average Loss= 6.0910
# Step 1280000, Average Loss= 6.3760
# Step 1290000, Average Loss= 6.3235
# Step 1300000, Average Loss= 6.4666
# Step 1310000, Average Loss= 6.2316
# Step 1320000, Average Loss= 6.2973
# Step 1330000, Average Loss= 6.3601
# Step 1340000, Average Loss= 6.2467
# Step 1350000, Average Loss= 6.2259
# Step 1360000, Average Loss= 6.2797
# Step 1370000, Average Loss= 6.2300
# Step 1380000, Average Loss= 6.2448
# Step 1390000, Average Loss= 6.2611
# Step 1400000, Average Loss= 6.2005
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'three', b'six', b'eight', b'seven', b'two', b'one', b'zero',
# "b'of'" nearest neighbors: b'the', b'including', b'and', b'its', b'for', b'especially', b'both', b'group',
# "b'going'" nearest neighbors: b'their', b'human', b'business', b'to', b'for', b'these', b'having', b'today',
# "b'hardware'" nearest neighbors: b'sound', b'itself', b'out', b'father', b'for', b'once', b'by', b'without',
# "b'american'" nearest neighbors: b'german', b'english', b'french', b'born', b'british', b'film', b'john', b's',
# "b'britain'" nearest neighbors: b'within', b'high', b'country', b'europe', b'its', b'level', b'along', b'air',
# Step 1410000, Average Loss= 6.2708
# Step 1420000, Average Loss= 6.2849
# Step 1430000, Average Loss= 6.2556
# Step 1440000, Average Loss= 6.2718
# Step 1450000, Average Loss= 6.1513
# Step 1460000, Average Loss= 6.1808
# Step 1470000, Average Loss= 6.2100
# Step 1480000, Average Loss= 6.1256
# Step 1490000, Average Loss= 6.2347
# Step 1500000, Average Loss= 6.1376
# Step 1510000, Average Loss= 6.1893
# Step 1520000, Average Loss= 6.0636
# Step 1530000, Average Loss= 5.9574
# Step 1540000, Average Loss= 6.0164
# Step 1550000, Average Loss= 6.1962
# Step 1560000, Average Loss= 6.0780
# Step 1570000, Average Loss= 6.1460
# Step 1580000, Average Loss= 5.9886
# Step 1590000, Average Loss= 6.0963
# Step 1600000, Average Loss= 6.1300
# Evaluation...
# "b'five'" nearest neighbors: b'three', b'four', b'six', b'seven', b'two', b'eight', b'zero', b'nine',
# "b'of'" nearest neighbors: b'the', b'and', b'in', b'from', b'including', b'its', b'for', b'through',
# "b'going'" nearest neighbors: b'business', b'these', b'an', b'several', b'take', b'only', b'today', b'some',
# "b'hardware'" nearest neighbors: b'sound', b'out', b'once', b'work', b'making', b'down', b'particular', b'for',
# "b'american'" nearest neighbors: b'born', b'english', b'german', b'british', b'french', b'b', b'd', b'john',
# "b'britain'" nearest neighbors: b'country', b'europe', b'along', b'its', b'near', b'high', b'air', b'within',
# Step 1610000, Average Loss= 6.0444
# Step 1620000, Average Loss= 6.0051
# Step 1630000, Average Loss= 6.1038
# Step 1640000, Average Loss= 6.0172
# Step 1650000, Average Loss= 6.0811
# Step 1660000, Average Loss= 5.9909
# Step 1670000, Average Loss= 6.0602
# Step 1680000, Average Loss= 6.1276
# Step 1690000, Average Loss= 6.0773
# Step 1700000, Average Loss= 6.0495
# Step 1710000, Average Loss= 6.0004
# Step 1720000, Average Loss= 6.0336
# Step 1730000, Average Loss= 5.9728
# Step 1740000, Average Loss= 6.0781
# Step 1750000, Average Loss= 5.9322
# Step 1760000, Average Loss= 6.0277
# Step 1770000, Average Loss= 5.9816
# Step 1780000, Average Loss= 5.9737
# Step 1790000, Average Loss= 5.9481
# Step 1800000, Average Loss= 5.7185
# Evaluation...
# "b'five'" nearest neighbors: b'three', b'four', b'seven', b'six', b'eight', b'nine', b'two', b'zero',
# "b'of'" nearest neighbors: b'the', b'became', b'in', b'from', b'first', b'and', b'including', b'following',
# "b'going'" nearest neighbors: b'business', b'several', b'take', b'some', b'these', b'their', b'up', b'today',
# "b'hardware'" nearest neighbors: b'sound', b'instead', b'out', b'once', b'original', b'down', b'making', b'up',
# "b'american'" nearest neighbors: b'd', b'b', b'born', b'actor', UNK, b'robert', b'john', b'nine',
# "b'britain'" nearest neighbors: b'country', b'europe', b'southern', b'established', b'along', b'especially', b'germany', b'government',
# Step 1810000, Average Loss= 5.9524
# Step 1820000, Average Loss= 5.9508
# Step 1830000, Average Loss= 6.0295
# Step 1840000, Average Loss= 5.8672
# Step 1850000, Average Loss= 5.9309
# Step 1860000, Average Loss= 5.9629
# Step 1870000, Average Loss= 5.9016
# Step 1880000, Average Loss= 5.8865
# Step 1890000, Average Loss= 5.9110
# Step 1900000, Average Loss= 5.9039
# Step 1910000, Average Loss= 5.8909
# Step 1920000, Average Loss= 5.9347
# Step 1930000, Average Loss= 5.8727
# Step 1940000, Average Loss= 5.9241
# Step 1950000, Average Loss= 5.9826
# Step 1960000, Average Loss= 5.9118
# Step 1970000, Average Loss= 5.9044
# Step 1980000, Average Loss= 5.8533
# Step 1990000, Average Loss= 5.8878
# Step 2000000, Average Loss= 5.8583
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'three', b'six', b'seven', b'two', b'eight', b'nine', b'zero',
# "b'of'" nearest neighbors: b'for', b'the', b'its', b'and', b'with', b'from', b'including', b'especially',
# "b'going'" nearest neighbors: b'their', b'business', b'but', b'several', b'held', b'every', b'received', b'them',
# "b'hardware'" nearest neighbors: b'sound', b'machine', b'out', b'original', b'making', b'instead', b'work', b'particular',
# "b'american'" nearest neighbors: b'born', b'd', b'actor', b'b', b'german', b'robert', b'italian', b'john',
# "b'britain'" nearest neighbors: b'country', b'europe', b'southern', b'germany', b'established', b'western', b'england', b'northern',
# Step 2010000, Average Loss= 5.9024
# Step 2020000, Average Loss= 5.8768
# Step 2030000, Average Loss= 5.8803
# Step 2040000, Average Loss= 5.8676
# Step 2050000, Average Loss= 5.8309
# Step 2060000, Average Loss= 5.7095
# Step 2070000, Average Loss= 5.6817
# Step 2080000, Average Loss= 5.8979
# Step 2090000, Average Loss= 5.7918
# Step 2100000, Average Loss= 5.9062
# Step 2110000, Average Loss= 5.6994
# Step 2120000, Average Loss= 5.8056
# Step 2130000, Average Loss= 5.8718
# Step 2140000, Average Loss= 5.8052
# Step 2150000, Average Loss= 5.7399
# Step 2160000, Average Loss= 5.8402
# Step 2170000, Average Loss= 5.7712
# Step 2180000, Average Loss= 5.8258
# Step 2190000, Average Loss= 5.7846
# Step 2200000, Average Loss= 5.7938
# Evaluation...
# "b'five'" nearest neighbors: b'four', b'three', b'six', b'two', b'eight', b'seven', b'one', b'zero',
# "b'of'" nearest neighbors: b'in', b'for', b'with', b'the', b'through', b'including', b'and', b'include',
# "b'going'" nearest neighbors: b'received', b'several', b'take', b'every', b'for', b'business', b'were', b'their',
# "b'hardware'" nearest neighbors: b'machine', b'sound', b'required', b'line', b'position', b'instead', b'original', b'network',
# "b'american'" nearest neighbors: b'german', b'canadian', b'english', b'french', b'british', b'author', b'italian', b'russian',
# "b'britain'" nearest neighbors: b'europe', b'england', b'canada', b'country', b'germany', b'northern', b'southern', b'british',
# Step 2210000, Average Loss= 5.8480
# Step 2220000, Average Loss= 5.8347
# Step 2230000, Average Loss= 5.8007
# Step 2240000, Average Loss= 5.8217
# Step 2250000, Average Loss= 5.7641
# Step 2260000, Average Loss= 5.7532
# Step 2270000, Average Loss= 5.8006
# Step 2280000, Average Loss= 5.7033
# Step 2290000, Average Loss= 5.8268
# Step 2300000, Average Loss= 5.7490
# Step 2310000, Average Loss= 5.8082
# Step 2320000, Average Loss= 5.6966
# Step 2330000, Average Loss= 5.5179
# Step 2340000, Average Loss= 5.6920
# Step 2350000, Average Loss= 5.7905
# Step 2360000, Average Loss= 5.7646
# Step 2370000, Average Loss= 5.6823
# Step 2380000, Average Loss= 5.7107
# Step 2390000, Average Loss= 5.7400
# Step 2400000, Average Loss= 5.7349
# Evaluation...
# "b'five'" nearest neighbors: b'three', b'four', b'six', b'two', b'seven', b'eight', b'nine', b'zero',
# "b'of'" nearest neighbors: b'the', b'from', b'and', b'in', b'including', b'included', b'following', b'original',
# "b'going'" nearest neighbors: b'business', b'their', b'up', b'however', b'received', b'results', b'take', b'several',
# "b'hardware'" nearest neighbors: b'machine', b'required', b'sound', b'line', b'making', b'model', b'standard', b'original',
# "b'american'" nearest neighbors: b'actor', b'born', b'author', b'canadian', b'british', b'b', b'english', b'd',
# "b'britain'" nearest neighbors: b'northern', b'england', b'canada', b'europe', b'germany', b'country', b'established', b'france',
# Step 2410000, Average Loss= 5.6640
# Step 2420000, Average Loss= 5.7203
# Step 2430000, Average Loss= 5.7089
# Step 2440000, Average Loss= 5.7183
